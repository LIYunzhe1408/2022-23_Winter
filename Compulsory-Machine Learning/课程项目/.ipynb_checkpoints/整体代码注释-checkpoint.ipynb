# %% [markdown]
# # 基于经典网络架构训练图像分类模型

# %% [markdown]
# ### 数据预处理部分：
#
# - 数据增强：torchvision中transforms模块自带功能，比较实用
# - 数据预处理：torchvision中transforms也帮我们实现好了，直接调用即可
# - DataLoader模块直接读取batch数据
#
# ### 网络模块设置：
#
# - 加载预训练模型，torchvision中有很多经典网络架构，调用起来十分方便，并且可以用人家训练好的权重参数来继续训练，也就是所谓的迁移学习
# - 需要注意的是别人训练好的任务跟咱们的可不是完全一样，需要把最后的head层改一改，一般也就是最后的全连接层，改成咱们自己的任务
# - 训练时可以全部重头训练，也可以只训练最后咱们任务的层，因为前几层都是做特征提取的，本质任务目标是一致的
#
# ### 网络模型保存与测试
# - 模型保存的时候可以带有选择性，例如在验证集中如果当前效果好则保存
# - 读取模型进行实际测试

# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import torch
from torch import nn
import torch.optim as optim
import torchvision
#pip install torchvision
from torchvision import transforms, models, datasets
#https://pytorch.org/docs/stable/torchvision/index.html
import imageio
import time
import warnings
import random
import sys
import copy
import json
from PIL import Image
# Out:
# E:\Anaconda\envs\Jonas\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21176\2954941029.py in <module>
#      10 from torchvision import transforms, models, datasets
#      11 #https://pytorch.org/docs/stable/torchvision/index.html
# ---> 12 import imageio
#      13 import time
#      14 import warnings
#
# ModuleNotFoundError: No module named 'imageio'

# %% [markdown]
# ### 数据读取与预处理操作

# %%
data_dir = './data/'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %% [markdown]
# ### 制作好数据源：
# - data_transforms中指定了所有图像预处理操作
# - ImageFolder假设所有的文件按文件夹保存好，每个文件夹下面存贮同一类别的图片，文件夹的名字为分类的名字

# %%
data_transforms = {
    'train': transforms.Compose([transforms.Resize(256),#标准化图片
        transforms.RandomRotation(45),#随机旋转，-45到45度之间随机选
        transforms.CenterCrop(224),#从中心开始裁剪
        transforms.RandomHorizontalFlip(p=0.5),#随机水平翻转 选择一个概率概率
        transforms.RandomVerticalFlip(p=0.5),#随机垂直翻转
        transforms.ColorJitter(brightness=0.2, contrast=0.1, saturation=0.1, hue=0.1),#参数1为亮度，参数2为对比度，参数3为饱和度，参数4为色相
        transforms.RandomGrayscale(p=0.025),#概率转换成灰度率，3通道就是R=G=B
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])#均值，标准差
    ]),
    'valid': transforms.Compose([transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
batch_size = 32
CLASS = 3
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'valid']}#构建数据集
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True) for x in ['train', 'valid']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid']}
class_names = image_datasets['train'].classes

# %%
image_datasets
# Out:
# {'train': Dataset ImageFolder
#      Number of datapoints: 5216
#      Root location: ./data/train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=256, interpolation=bilinear)
#                 RandomRotation(degrees=[-45.0, 45.0], interpolation=nearest, expand=False, fill=0)
#                 CenterCrop(size=(224, 224))
#                 RandomHorizontalFlip(p=0.5)
#                 RandomVerticalFlip(p=0.5)
#                 ColorJitter(brightness=[0.8, 1.2], contrast=[0.9, 1.1], saturation=[0.9, 1.1], hue=[-0.1, 0.1])
#                 RandomGrayscale(p=0.025)
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             ),
#  'valid': Dataset ImageFolder
#      Number of datapoints: 624
#      Root location: ./data/valid
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=256, interpolation=bilinear)
#                 CenterCrop(size=(224, 224))
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             )}

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x200e4596f48>,
#  'valid': <torch.utils.data.dataloader.DataLoader at 0x200e4674048>}

# %%
dataset_sizes
# Out:
# {'train': 5216, 'valid': 624}

# %% [markdown]
# ### 读取标签对应的实际名字

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
cat_to_name
# Out:
# {'1': 'BACTERIA', '2': 'NORMAL', '3': 'VIRUS'}

# %% [markdown]
# ### 展示下数据
# - 注意tensor的数据需要转换成numpy的格式，而且还需要还原回标准化的结果

# %%
def im_convert(tensor):
    """ 展示数据"""
    
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1,2,0)
    image = image * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
    image = image.clip(0, 1)

    return image

# %%
fig=plt.figure(figsize=(20, 12))
columns = 4
rows = 2

dataiter = iter(dataloaders['valid'])
inputs, classes = dataiter.next()

for idx in range (columns*rows):
    ax = fig.add_subplot(rows, columns, idx+1, xticks=[], yticks=[])
    ax.set_title(cat_to_name[str(int(class_names[classes[idx]]))])
    plt.imshow(im_convert(inputs[idx]))
plt.show()

# %% [markdown]
# ### 加载models中提供的模型，并且直接用训练的好权重当做初始化参数
# - 第一次执行需要下载，可能会比较慢，我会提供给大家一份下载好的，可以直接放到相应路径

# %%
model_name = 'resnet'  #可选的比较多 ['resnet', 'alexnet', 'vgg', 'squeezenet', 'densenet', 'inception']
#是否用人家训练好的特征来做
feature_extract = True

# %%
# 是否用GPU训练
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# CUDA is available!  Training on GPU ...

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
model_ft = models.resnet152()
model_ft
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# ### 参考pytorch官网例子

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # 选择合适的模型，不同模型的初始化方法稍微有点区别
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet152
        """
        model_ft = models.resnet152(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Sequential(nn.Linear(num_ftrs, CLASS),
                                   nn.LogSoftmax(dim=1))
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg16(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# %% [markdown]
# ### 设置哪些层需要训练

# %%
model_ft, input_size = initialize_model(model_name, CLASS, feature_extract, use_pretrained=True)

#GPU计算
model_ft = model_ft.to(device)

# 模型保存
filename='checkpoint.pth'

# 是否训练所有层
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)
# Out:
# Params to learn:
# 	 fc.0.weight
# 	 fc.0.bias

# %%
model_ft
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=3, bias=True)
#     (1): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# ### 优化器设置

# %%
# 优化器设置
optimizer_ft = optim.Adam(params_to_update, lr=1e-2)#设置学习率
scheduler = optim.lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)#学习率每7个epoch衰减成原来的1/10
#最后一层已经LogSoftmax()了，所以不能nn.CrossEntropyLoss()来计算了，nn.CrossEntropyLoss()相当于logSoftmax()和nn.NLLLoss()整合
criterion = nn.NLLLoss()

# %% [markdown]
# ### 训练模块

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs, is_inception=False,filename=filename):
    since = time.time()
    best_acc = 0
    """
    checkpoint = torch.load(filename)
    best_acc = checkpoint['best_acc']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    model.class_to_idx = checkpoint['mapping']
    """
    model.to(device)

    val_acc_history = []
    train_acc_history = []
    train_losses = []
    valid_losses = []
    LRs = [optimizer.param_groups[0]['lr']]

    best_model_wts = copy.deepcopy(model.state_dict())#得到实时最好的模型

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # 训练和验证
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # 训练
            else:
                model.eval()   # 验证

            running_loss = 0.0
            running_corrects = 0

            # 把数据都取个遍
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # 清零
                optimizer.zero_grad()
                # 只有训练的时候计算和更新梯度
                with torch.set_grad_enabled(phase == 'train'):
                    if is_inception and phase == 'train':
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:#resnet执行的是这里
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # 训练阶段更新权重
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # 计算损失
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            
            
            time_elapsed = time.time() - since
            print('Time elapsed {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
            

            # 得到最好那次的模型
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                state = {
                  'state_dict': model.state_dict(),
                  'best_acc': best_acc,
                  'optimizer' : optimizer.state_dict(),
                }
                torch.save(state, filename)
            if phase == 'valid':
                val_acc_history.append(epoch_acc)
                valid_losses.append(epoch_loss)
                scheduler.step(epoch_loss)
            if phase == 'train':
                train_acc_history.append(epoch_acc)
                train_losses.append(epoch_loss)
        
        print('Optimizer learning rate : {:.7f}'.format(optimizer.param_groups[0]['lr']))
        LRs.append(optimizer.param_groups[0]['lr'])
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # 训练完后用最好的一次当做模型最终的结果
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, train_acc_history, valid_losses, train_losses, LRs

# %% [markdown]
# ### 开始训练！

# %%
model_ft, val_acc_history, train_acc_history, valid_losses, train_losses, LRs  = train_model(model_ft, dataloaders, criterion, optimizer_ft, num_epochs=150, is_inception=(model_name=="inception"))
# Out:
# Epoch 0/149
# ----------
# Time elapsed 1m 36s
# train Loss: 1.1092 Acc: 0.6275
# Time elapsed 1m 47s
# valid Loss: 1.2867 Acc: 0.5737
# C:\Users\15690\.conda\envs\ltc37\lib\site-packages\torch\optim\lr_scheduler.py:154: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Optimizer learning rate : 0.0100000
#
# Epoch 1/149
# ----------
# Time elapsed 3m 22s
# train Loss: 0.9445 Acc: 0.6666
# Time elapsed 3m 32s
# valid Loss: 1.3777 Acc: 0.5929
# Optimizer learning rate : 0.0100000
#
# Epoch 2/149
# ----------
# Time elapsed 5m 8s
# train Loss: 1.0204 Acc: 0.6773
# Time elapsed 5m 18s
# valid Loss: 0.8643 Acc: 0.7212
# Optimizer learning rate : 0.0100000
#
# Epoch 3/149
# ----------
# Time elapsed 6m 55s
# train Loss: 1.0652 Acc: 0.6651
# Time elapsed 7m 5s
# valid Loss: 1.3073 Acc: 0.5769
# Optimizer learning rate : 0.0100000
#
# Epoch 4/149
# ----------
# Time elapsed 8m 41s
# train Loss: 0.8996 Acc: 0.6921
# Time elapsed 8m 51s
# valid Loss: 1.3372 Acc: 0.6731
# Optimizer learning rate : 0.0100000
#
# Epoch 5/149
# ----------
# Time elapsed 10m 27s
# train Loss: 0.9793 Acc: 0.6739
# Time elapsed 10m 37s
# valid Loss: 2.2809 Acc: 0.5256
# Optimizer learning rate : 0.0100000
#
# Epoch 6/149
# ----------
# Time elapsed 12m 13s
# train Loss: 0.9094 Acc: 0.6956
# Time elapsed 12m 23s
# valid Loss: 0.9922 Acc: 0.7051
# Optimizer learning rate : 0.0100000
#
# Epoch 7/149
# ----------
# Time elapsed 13m 58s
# train Loss: 0.8988 Acc: 0.6980
# Time elapsed 14m 9s
# valid Loss: 1.5665 Acc: 0.6218
# Optimizer learning rate : 0.0100000
#
# Epoch 8/149
# ----------
# Time elapsed 15m 44s
# train Loss: 1.0422 Acc: 0.6756
# Time elapsed 15m 55s
# valid Loss: 2.2408 Acc: 0.5369
# Optimizer learning rate : 0.0100000
#
# Epoch 9/149
# ----------
# Time elapsed 17m 32s
# train Loss: 0.9195 Acc: 0.7044
# Time elapsed 17m 42s
# valid Loss: 1.7775 Acc: 0.6410
# Optimizer learning rate : 0.0100000
#
# Epoch 10/149
# ----------
# Time elapsed 19m 17s
# train Loss: 0.8747 Acc: 0.7040
# Time elapsed 19m 28s
# valid Loss: 2.1119 Acc: 0.5913
# Optimizer learning rate : 0.0100000
#
# Epoch 11/149
# ----------
# Time elapsed 21m 2s
# train Loss: 0.8670 Acc: 0.7005
# Time elapsed 21m 13s
# valid Loss: 0.8154 Acc: 0.7308
# Optimizer learning rate : 0.0100000
#
# Epoch 12/149
# ----------
# Time elapsed 22m 49s
# train Loss: 0.9743 Acc: 0.6890
# Time elapsed 22m 59s
# valid Loss: 1.5177 Acc: 0.6122
# Optimizer learning rate : 0.0100000
#
# Epoch 13/149
# ----------
# Time elapsed 24m 35s
# train Loss: 1.0181 Acc: 0.6963
# Time elapsed 24m 45s
# valid Loss: 1.2983 Acc: 0.6330
# Optimizer learning rate : 0.0100000
#
# Epoch 14/149
# ----------
# Time elapsed 26m 22s
# train Loss: 1.0697 Acc: 0.6913
# Time elapsed 26m 32s
# valid Loss: 3.1872 Acc: 0.5417
# Optimizer learning rate : 0.0100000
#
# Epoch 15/149
# ----------
# Time elapsed 28m 8s
# train Loss: 0.9288 Acc: 0.7042
# Time elapsed 28m 19s
# valid Loss: 1.1725 Acc: 0.7067
# Optimizer learning rate : 0.0100000
#
# Epoch 16/149
# ----------
# Time elapsed 29m 55s
# train Loss: 0.6997 Acc: 0.7314
# Time elapsed 30m 5s
# valid Loss: 0.7769 Acc: 0.7628
# Optimizer learning rate : 0.0100000
#
# Epoch 17/149
# ----------
# Time elapsed 31m 41s
# train Loss: 1.0385 Acc: 0.6887
# Time elapsed 31m 52s
# valid Loss: 1.0147 Acc: 0.7676
# Optimizer learning rate : 0.0100000
#
# Epoch 18/149
# ----------
# Time elapsed 33m 28s
# train Loss: 0.7605 Acc: 0.7228
# Time elapsed 33m 38s
# valid Loss: 1.3559 Acc: 0.6955
# Optimizer learning rate : 0.0100000
#
# Epoch 19/149
# ----------
# Time elapsed 35m 15s
# train Loss: 0.9542 Acc: 0.6973
# Time elapsed 35m 26s
# valid Loss: 1.5326 Acc: 0.7035
# Optimizer learning rate : 0.0100000
#
# Epoch 20/149
# ----------
# Time elapsed 37m 2s
# train Loss: 0.8479 Acc: 0.7189
# Time elapsed 37m 13s
# valid Loss: 1.1016 Acc: 0.7356
# Optimizer learning rate : 0.0100000
#
# Epoch 21/149
# ----------
# Time elapsed 38m 48s
# train Loss: 0.9884 Acc: 0.6959
# Time elapsed 38m 58s
# valid Loss: 2.4170 Acc: 0.6058
# Optimizer learning rate : 0.0100000
#
# Epoch 22/149
# ----------
# Time elapsed 40m 34s
# train Loss: 0.8284 Acc: 0.7201
# Time elapsed 40m 44s
# valid Loss: 1.0145 Acc: 0.7340
# Optimizer learning rate : 0.0100000
#
# Epoch 23/149
# ----------
# Time elapsed 42m 20s
# train Loss: 0.9141 Acc: 0.7189
# Time elapsed 42m 31s
# valid Loss: 1.0969 Acc: 0.6699
# Optimizer learning rate : 0.0100000
#
# Epoch 24/149
# ----------
# Time elapsed 44m 7s
# train Loss: 1.0069 Acc: 0.7021
# Time elapsed 44m 18s
# valid Loss: 1.2555 Acc: 0.7131
# Optimizer learning rate : 0.0100000
#
# Epoch 25/149
# ----------
# Time elapsed 45m 54s
# train Loss: 0.8515 Acc: 0.7049
# Time elapsed 46m 5s
# valid Loss: 1.8177 Acc: 0.5946
# Optimizer learning rate : 0.0100000
#
# Epoch 26/149
# ----------
# Time elapsed 47m 45s
# train Loss: 0.9653 Acc: 0.7019
# Time elapsed 47m 56s
# valid Loss: 0.8040 Acc: 0.7949
# Optimizer learning rate : 0.0100000
#
# Epoch 27/149
# ----------
# Time elapsed 49m 35s
# train Loss: 0.8380 Acc: 0.7126
# Time elapsed 49m 46s
# valid Loss: 3.3023 Acc: 0.5561
# Optimizer learning rate : 0.0100000
#
# Epoch 28/149
# ----------
# Time elapsed 51m 26s
# train Loss: 0.8845 Acc: 0.7094
# Time elapsed 51m 36s
# valid Loss: 3.5959 Acc: 0.4888
# Optimizer learning rate : 0.0100000
#
# Epoch 29/149
# ----------
# Time elapsed 53m 16s
# train Loss: 1.0833 Acc: 0.6911
# Time elapsed 53m 26s
# valid Loss: 1.0069 Acc: 0.7468
# Optimizer learning rate : 0.0100000
#
# Epoch 30/149
# ----------
# Time elapsed 55m 4s
# train Loss: 0.8912 Acc: 0.7107
# Time elapsed 55m 16s
# valid Loss: 1.9334 Acc: 0.6394
# Optimizer learning rate : 0.0100000
#
# Epoch 31/149
# ----------
# Time elapsed 56m 54s
# train Loss: 1.0172 Acc: 0.6950
# Time elapsed 57m 5s
# valid Loss: 1.3207 Acc: 0.6330
# Optimizer learning rate : 0.0100000
#
# Epoch 32/149
# ----------
# Time elapsed 58m 44s
# train Loss: 0.9414 Acc: 0.7115
# Time elapsed 58m 55s
# valid Loss: 0.7631 Acc: 0.7804
# Optimizer learning rate : 0.0100000
#
# Epoch 33/149
# ----------
# Time elapsed 60m 34s
# train Loss: 0.8513 Acc: 0.7080
# Time elapsed 60m 45s
# valid Loss: 0.9220 Acc: 0.7292
# Optimizer learning rate : 0.0100000
#
# Epoch 34/149
# ----------
# Time elapsed 62m 24s
# train Loss: 0.8568 Acc: 0.7124
# Time elapsed 62m 35s
# valid Loss: 1.2485 Acc: 0.6506
# Optimizer learning rate : 0.0100000
#
# Epoch 35/149
# ----------
# Time elapsed 64m 14s
# train Loss: 0.8880 Acc: 0.7090
# Time elapsed 64m 25s
# valid Loss: 0.9714 Acc: 0.7324
# Optimizer learning rate : 0.0100000
#
# Epoch 36/149
# ----------
# Time elapsed 66m 4s
# train Loss: 0.9963 Acc: 0.7026
# Time elapsed 66m 15s
# valid Loss: 1.0180 Acc: 0.7612
# Optimizer learning rate : 0.0100000
#
# Epoch 37/149
# ----------
# Time elapsed 67m 54s
# train Loss: 1.0341 Acc: 0.6950
# Time elapsed 68m 5s
# valid Loss: 1.3399 Acc: 0.6827
# Optimizer learning rate : 0.0100000
#
# Epoch 38/149
# ----------
# Time elapsed 69m 44s
# train Loss: 0.8442 Acc: 0.7230
# Time elapsed 69m 54s
# valid Loss: 1.3391 Acc: 0.7115
# Optimizer learning rate : 0.0100000
#
# Epoch 39/149
# ----------
# Time elapsed 71m 33s
# train Loss: 0.9112 Acc: 0.7019
# Time elapsed 71m 44s
# valid Loss: 2.5545 Acc: 0.5785
# Optimizer learning rate : 0.0100000
#
# Epoch 40/149
# ----------
# Time elapsed 73m 22s
# train Loss: 0.8183 Acc: 0.7163
# Time elapsed 73m 33s
# valid Loss: 1.2213 Acc: 0.7244
# Optimizer learning rate : 0.0100000
#
# Epoch 41/149
# ----------
# Time elapsed 75m 12s
# train Loss: 0.8531 Acc: 0.7207
# Time elapsed 75m 23s
# valid Loss: 2.0395 Acc: 0.5673
# Optimizer learning rate : 0.0100000
#
# Epoch 42/149
# ----------
# Time elapsed 77m 1s
# train Loss: 0.7321 Acc: 0.7381
# Time elapsed 77m 12s
# valid Loss: 1.4115 Acc: 0.6474
# Optimizer learning rate : 0.0100000
#
# Epoch 43/149
# ----------
# Time elapsed 78m 48s
# train Loss: 0.8869 Acc: 0.7107
# Time elapsed 78m 58s
# valid Loss: 2.2039 Acc: 0.5641
# Optimizer learning rate : 0.0100000
#
# Epoch 44/149
# ----------
# Time elapsed 80m 31s
# train Loss: 0.8846 Acc: 0.7255
# Time elapsed 80m 41s
# valid Loss: 1.1202 Acc: 0.7340
# Optimizer learning rate : 0.0100000
#
# Epoch 45/149
# ----------
# Time elapsed 82m 13s
# train Loss: 0.8044 Acc: 0.7264
# Time elapsed 82m 24s
# valid Loss: 2.0947 Acc: 0.6346
# Optimizer learning rate : 0.0100000
#
# Epoch 46/149
# ----------
# Time elapsed 83m 60s
# train Loss: 0.8940 Acc: 0.7191
# Time elapsed 84m 10s
# valid Loss: 1.1541 Acc: 0.7484
# Optimizer learning rate : 0.0100000
#
# Epoch 47/149
# ----------
# Time elapsed 85m 46s
# train Loss: 0.9872 Acc: 0.7000
# Time elapsed 85m 56s
# valid Loss: 1.5627 Acc: 0.6603
# Optimizer learning rate : 0.0100000
#
# Epoch 48/149
# ----------
# Time elapsed 87m 32s
# train Loss: 0.7915 Acc: 0.7211
# Time elapsed 87m 43s
# valid Loss: 0.8196 Acc: 0.7740
# Optimizer learning rate : 0.0100000
#
# Epoch 49/149
# ----------
# Time elapsed 89m 19s
# train Loss: 0.8524 Acc: 0.7266
# Time elapsed 89m 30s
# valid Loss: 0.8812 Acc: 0.7724
# Optimizer learning rate : 0.0100000
#
# Epoch 50/149
# ----------
# Time elapsed 91m 5s
# train Loss: 0.8319 Acc: 0.7297
# Time elapsed 91m 16s
# valid Loss: 1.8110 Acc: 0.6170
# Optimizer learning rate : 0.0100000
#
# Epoch 51/149
# ----------
# Time elapsed 92m 52s
# train Loss: 0.8295 Acc: 0.7130
# Time elapsed 93m 2s
# valid Loss: 0.7930 Acc: 0.7756
# Optimizer learning rate : 0.0100000
#
# Epoch 52/149
# ----------
# Time elapsed 94m 38s
# train Loss: 0.9234 Acc: 0.7161
# Time elapsed 94m 48s
# valid Loss: 1.0776 Acc: 0.7516
# Optimizer learning rate : 0.0100000
#
# Epoch 53/149
# ----------
# Time elapsed 96m 25s
# train Loss: 0.8482 Acc: 0.7164
# Time elapsed 96m 35s
# valid Loss: 1.3687 Acc: 0.6843
# Optimizer learning rate : 0.0100000
#
# Epoch 54/149
# ----------
# Time elapsed 98m 11s
# train Loss: 0.9569 Acc: 0.7105
# Time elapsed 98m 21s
# valid Loss: 0.9125 Acc: 0.7772
# Optimizer learning rate : 0.0100000
#
# Epoch 55/149
# ----------
# Time elapsed 99m 57s
# train Loss: 0.8957 Acc: 0.7161
# Time elapsed 100m 8s
# valid Loss: 1.1590 Acc: 0.7212
# Optimizer learning rate : 0.0100000
#
# Epoch 56/149
# ----------
# Time elapsed 101m 44s
# train Loss: 0.8614 Acc: 0.7235
# Time elapsed 101m 55s
# valid Loss: 1.0773 Acc: 0.7196
# Optimizer learning rate : 0.0100000
#
# Epoch 57/149
# ----------
# Time elapsed 103m 31s
# train Loss: 0.8176 Acc: 0.7220
# Time elapsed 103m 41s
# valid Loss: 1.6668 Acc: 0.6362
# Optimizer learning rate : 0.0100000
#
# Epoch 58/149
# ----------
# Time elapsed 105m 17s
# train Loss: 0.8882 Acc: 0.7111
# Time elapsed 105m 27s
# valid Loss: 1.2956 Acc: 0.7292
# Optimizer learning rate : 0.0100000
#
# Epoch 59/149
# ----------
# Time elapsed 107m 5s
# train Loss: 0.9931 Acc: 0.7094
# Time elapsed 107m 15s
# valid Loss: 2.0546 Acc: 0.5994
# Optimizer learning rate : 0.0100000
#
# Epoch 60/149
# ----------
# Time elapsed 108m 52s
# train Loss: 0.9234 Acc: 0.7176
# Time elapsed 109m 2s
# valid Loss: 1.8146 Acc: 0.6603
# Optimizer learning rate : 0.0100000
#
# Epoch 61/149
# ----------
# Time elapsed 110m 39s
# train Loss: 0.9283 Acc: 0.7149
# Time elapsed 110m 49s
# valid Loss: 1.4900 Acc: 0.6298
# Optimizer learning rate : 0.0100000
#
# Epoch 62/149
# ----------
# Time elapsed 112m 25s
# train Loss: 0.9627 Acc: 0.7061
# Time elapsed 112m 36s
# valid Loss: 2.0967 Acc: 0.6458
# Optimizer learning rate : 0.0100000
#
# Epoch 63/149
# ----------
# Time elapsed 114m 12s
# train Loss: 0.7780 Acc: 0.7331
# Time elapsed 114m 23s
# valid Loss: 1.1904 Acc: 0.7099
# Optimizer learning rate : 0.0100000
#
# Epoch 64/149
# ----------
# Time elapsed 115m 59s
# train Loss: 0.8901 Acc: 0.7149
# Time elapsed 116m 9s
# valid Loss: 1.0500 Acc: 0.7292
# Optimizer learning rate : 0.0100000
#
# Epoch 65/149
# ----------
# Time elapsed 117m 45s
# train Loss: 0.8708 Acc: 0.7243
# Time elapsed 117m 56s
# valid Loss: 1.4311 Acc: 0.6522
# Optimizer learning rate : 0.0100000
#
# Epoch 66/149
# ----------
# Time elapsed 119m 33s
# train Loss: 0.8501 Acc: 0.7264
# Time elapsed 119m 44s
# valid Loss: 1.1876 Acc: 0.6875
# Optimizer learning rate : 0.0100000
#
# Epoch 67/149
# ----------
# Time elapsed 121m 19s
# train Loss: 0.8874 Acc: 0.7249
# Time elapsed 121m 29s
# valid Loss: 0.9428 Acc: 0.7821
# Optimizer learning rate : 0.0100000
#
# Epoch 68/149
# ----------
# Time elapsed 123m 5s
# train Loss: 0.8153 Acc: 0.7197
# Time elapsed 123m 15s
# valid Loss: 1.7295 Acc: 0.6170
# Optimizer learning rate : 0.0100000
#
# Epoch 69/149
# ----------
# Time elapsed 124m 51s
# train Loss: 1.0271 Acc: 0.6980
# Time elapsed 125m 2s
# valid Loss: 1.0983 Acc: 0.7676
# Optimizer learning rate : 0.0100000
#
# Epoch 70/149
# ----------
# Time elapsed 126m 38s
# train Loss: 0.9125 Acc: 0.7211
# Time elapsed 126m 48s
# valid Loss: 1.2788 Acc: 0.6875
# Optimizer learning rate : 0.0100000
#
# Epoch 71/149
# ----------
# Time elapsed 128m 24s
# train Loss: 0.9727 Acc: 0.7057
# Time elapsed 128m 34s
# valid Loss: 1.4171 Acc: 0.7051
# Optimizer learning rate : 0.0100000
#
# Epoch 72/149
# ----------
# Time elapsed 130m 10s
# train Loss: 0.7448 Acc: 0.7358
# Time elapsed 130m 21s
# valid Loss: 2.4425 Acc: 0.5737
# Optimizer learning rate : 0.0100000
#
# Epoch 73/149
# ----------
# Time elapsed 131m 56s
# train Loss: 0.8492 Acc: 0.7184
# Time elapsed 132m 7s
# valid Loss: 1.2739 Acc: 0.7067
# Optimizer learning rate : 0.0100000
#
# Epoch 74/149
# ----------
# Time elapsed 133m 43s
# train Loss: 0.8195 Acc: 0.7278
# Time elapsed 133m 53s
# valid Loss: 1.1522 Acc: 0.7308
# Optimizer learning rate : 0.0100000
#
# Epoch 75/149
# ----------
# Time elapsed 135m 30s
# train Loss: 0.8118 Acc: 0.7312
# Time elapsed 135m 40s
# valid Loss: 2.0192 Acc: 0.6554
# Optimizer learning rate : 0.0100000
#
# Epoch 76/149
# ----------
# Time elapsed 137m 17s
# train Loss: 0.8350 Acc: 0.7274
# Time elapsed 137m 27s
# valid Loss: 1.4569 Acc: 0.6875
# Optimizer learning rate : 0.0100000
#
# Epoch 77/149
# ----------
# Time elapsed 139m 3s
# train Loss: 0.9770 Acc: 0.7090
# Time elapsed 139m 13s
# valid Loss: 2.4063 Acc: 0.6170
# Optimizer learning rate : 0.0100000
#
# Epoch 78/149
# ----------
# Time elapsed 140m 50s
# train Loss: 0.7607 Acc: 0.7312
# Time elapsed 141m 1s
# valid Loss: 1.2023 Acc: 0.7372
# Optimizer learning rate : 0.0100000
#
# Epoch 79/149
# ----------
# Time elapsed 142m 38s
# train Loss: 0.8801 Acc: 0.7138
# Time elapsed 142m 48s
# valid Loss: 1.8029 Acc: 0.6474
# Optimizer learning rate : 0.0100000
#
# Epoch 80/149
# ----------
# Time elapsed 144m 27s
# train Loss: 0.8587 Acc: 0.7138
# Time elapsed 144m 37s
# valid Loss: 3.5524 Acc: 0.4439
# Optimizer learning rate : 0.0100000
#
# Epoch 81/149
# ----------
# Time elapsed 146m 16s
# train Loss: 0.8764 Acc: 0.7232
# Time elapsed 146m 26s
# valid Loss: 1.2550 Acc: 0.6939
# Optimizer learning rate : 0.0100000
#
# Epoch 82/149
# ----------
# Time elapsed 148m 6s
# train Loss: 0.8989 Acc: 0.7214
# Time elapsed 148m 17s
# valid Loss: 1.1593 Acc: 0.7532
# Optimizer learning rate : 0.0100000
#
# Epoch 83/149
# ----------
# Time elapsed 149m 56s
# train Loss: 0.8345 Acc: 0.7270
# Time elapsed 150m 7s
# valid Loss: 1.4635 Acc: 0.6923
# Optimizer learning rate : 0.0100000
#
# Epoch 84/149
# ----------
# Time elapsed 151m 46s
# train Loss: 1.0342 Acc: 0.7132
# Time elapsed 151m 57s
# valid Loss: 1.5950 Acc: 0.6907
# Optimizer learning rate : 0.0100000
#
# Epoch 85/149
# ----------
# Time elapsed 153m 35s
# train Loss: 0.9349 Acc: 0.7153
# Time elapsed 153m 46s
# valid Loss: 2.1252 Acc: 0.6571
# Optimizer learning rate : 0.0100000
#
# Epoch 86/149
# ----------
# Time elapsed 155m 24s
# train Loss: 0.9769 Acc: 0.7128
# Time elapsed 155m 35s
# valid Loss: 1.3770 Acc: 0.7019
# Optimizer learning rate : 0.0100000
#
# Epoch 87/149
# ----------
# Time elapsed 157m 14s
# train Loss: 0.8890 Acc: 0.7168
# Time elapsed 157m 25s
# valid Loss: 2.1530 Acc: 0.5897
# Optimizer learning rate : 0.0100000
#
# Epoch 88/149
# ----------
# Time elapsed 159m 4s
# train Loss: 0.7444 Acc: 0.7414
# Time elapsed 159m 15s
# valid Loss: 1.5375 Acc: 0.6763
# Optimizer learning rate : 0.0100000
#
# Epoch 89/149
# ----------
# Time elapsed 160m 55s
# train Loss: 0.8757 Acc: 0.7178
# Time elapsed 161m 6s
# valid Loss: 1.9889 Acc: 0.5946
# Optimizer learning rate : 0.0100000
#
# Epoch 90/149
# ----------
# Time elapsed 162m 45s
# train Loss: 0.9745 Acc: 0.7086
# Time elapsed 162m 55s
# valid Loss: 0.8589 Acc: 0.8045
# Optimizer learning rate : 0.0100000
#
# Epoch 91/149
# ----------
# Time elapsed 164m 34s
# train Loss: 1.0022 Acc: 0.7084
# Time elapsed 164m 45s
# valid Loss: 1.0513 Acc: 0.7212
# Optimizer learning rate : 0.0100000
#
# Epoch 92/149
# ----------
# Time elapsed 166m 23s
# train Loss: 0.7801 Acc: 0.7387
# Time elapsed 166m 34s
# valid Loss: 1.8627 Acc: 0.6571
# Optimizer learning rate : 0.0100000
#
# Epoch 93/149
# ----------
# Time elapsed 168m 13s
# train Loss: 0.8207 Acc: 0.7243
# Time elapsed 168m 24s
# valid Loss: 0.9244 Acc: 0.7949
# Optimizer learning rate : 0.0100000
#
# Epoch 94/149
# ----------
# Time elapsed 170m 3s
# train Loss: 0.8255 Acc: 0.7247
# Time elapsed 170m 14s
# valid Loss: 3.5067 Acc: 0.5417
# Optimizer learning rate : 0.0100000
#
# Epoch 95/149
# ----------
# Time elapsed 171m 54s
# train Loss: 1.0722 Acc: 0.7076
# Time elapsed 172m 4s
# valid Loss: 2.0232 Acc: 0.6090
# Optimizer learning rate : 0.0100000
#
# Epoch 96/149
# ----------
# Time elapsed 173m 38s
# train Loss: 0.8184 Acc: 0.7331
# Time elapsed 173m 48s
# valid Loss: 1.3083 Acc: 0.7484
# Optimizer learning rate : 0.0100000
#
# Epoch 97/149
# ----------
# Time elapsed 175m 20s
# train Loss: 0.8061 Acc: 0.7308
# Time elapsed 175m 30s
# valid Loss: 4.1618 Acc: 0.5577
# Optimizer learning rate : 0.0100000
#
# Epoch 98/149
# ----------
# Time elapsed 177m 6s
# train Loss: 0.8940 Acc: 0.7243
# Time elapsed 177m 16s
# valid Loss: 1.1548 Acc: 0.7260
# Optimizer learning rate : 0.0100000
#
# Epoch 99/149
# ----------
# Time elapsed 178m 53s
# train Loss: 0.8762 Acc: 0.7289
# Time elapsed 179m 3s
# valid Loss: 1.6383 Acc: 0.6827
# Optimizer learning rate : 0.0100000
#
# Epoch 100/149
# ----------
# Time elapsed 180m 39s
# train Loss: 1.0164 Acc: 0.7128
# Time elapsed 180m 49s
# valid Loss: 1.7734 Acc: 0.6827
# Optimizer learning rate : 0.0100000
#
# Epoch 101/149
# ----------
# Time elapsed 182m 25s
# train Loss: 0.8914 Acc: 0.7260
# Time elapsed 182m 35s
# valid Loss: 2.4313 Acc: 0.5929
# Optimizer learning rate : 0.0100000
#
# Epoch 102/149
# ----------
# Time elapsed 184m 11s
# train Loss: 0.9467 Acc: 0.7220
# Time elapsed 184m 21s
# valid Loss: 1.6767 Acc: 0.6587
# Optimizer learning rate : 0.0100000
#
# Epoch 103/149
# ----------
# Time elapsed 185m 56s
# train Loss: 0.9188 Acc: 0.7095
# Time elapsed 186m 7s
# valid Loss: 1.8300 Acc: 0.6715
# Optimizer learning rate : 0.0100000
#
# Epoch 104/149
# ----------
# Time elapsed 187m 43s
# train Loss: 0.8267 Acc: 0.7291
# Time elapsed 187m 53s
# valid Loss: 1.0331 Acc: 0.7724
# Optimizer learning rate : 0.0100000
#
# Epoch 105/149
# ----------
# Time elapsed 189m 28s
# train Loss: 1.1304 Acc: 0.7069
# Time elapsed 189m 39s
# valid Loss: 1.8591 Acc: 0.6843
# Optimizer learning rate : 0.0100000
#
# Epoch 106/149
# ----------
# Time elapsed 191m 15s
# train Loss: 0.7795 Acc: 0.7326
# Time elapsed 191m 25s
# valid Loss: 1.0229 Acc: 0.7724
# Optimizer learning rate : 0.0100000
#
# Epoch 107/149
# ----------
# Time elapsed 193m 1s
# train Loss: 0.8982 Acc: 0.7228
# Time elapsed 193m 12s
# valid Loss: 1.0596 Acc: 0.7708
# Optimizer learning rate : 0.0100000
#
# Epoch 108/149
# ----------
# Time elapsed 194m 47s
# train Loss: 0.8226 Acc: 0.7352
# Time elapsed 194m 58s
# valid Loss: 1.2187 Acc: 0.7276
# Optimizer learning rate : 0.0100000
#
# Epoch 109/149
# ----------
# Time elapsed 196m 34s
# train Loss: 0.8088 Acc: 0.7406
# Time elapsed 196m 44s
# valid Loss: 1.6683 Acc: 0.6811
# Optimizer learning rate : 0.0100000
#
# Epoch 110/149
# ----------
# Time elapsed 198m 19s
# train Loss: 0.7670 Acc: 0.7316
# Time elapsed 198m 29s
# valid Loss: 1.2651 Acc: 0.7260
# Optimizer learning rate : 0.0100000
#
# Epoch 111/149
# ----------
# Time elapsed 200m 5s
# train Loss: 0.8596 Acc: 0.7274
# Time elapsed 200m 15s
# valid Loss: 1.7362 Acc: 0.6042
# Optimizer learning rate : 0.0100000
#
# Epoch 112/149
# ----------
# Time elapsed 201m 50s
# train Loss: 0.8465 Acc: 0.7358
# Time elapsed 202m 1s
# valid Loss: 1.4367 Acc: 0.6506
# Optimizer learning rate : 0.0100000
#
# Epoch 113/149
# ----------
# Time elapsed 203m 36s
# train Loss: 0.8973 Acc: 0.7184
# Time elapsed 203m 46s
# valid Loss: 1.4873 Acc: 0.7212
# Optimizer learning rate : 0.0100000
#
# Epoch 114/149
# ----------
# Time elapsed 205m 22s
# train Loss: 0.8901 Acc: 0.7193
# Time elapsed 205m 32s
# valid Loss: 3.3558 Acc: 0.5080
# Optimizer learning rate : 0.0100000
#
# Epoch 115/149
# ----------
# Time elapsed 207m 8s
# train Loss: 0.7942 Acc: 0.7347
# Time elapsed 207m 19s
# valid Loss: 3.0142 Acc: 0.4888
# Optimizer learning rate : 0.0100000
#
# Epoch 116/149
# ----------
# Time elapsed 208m 55s
# train Loss: 0.8932 Acc: 0.7130
# Time elapsed 209m 5s
# valid Loss: 1.9639 Acc: 0.6506
# Optimizer learning rate : 0.0100000
#
# Epoch 117/149
# ----------
# Time elapsed 210m 41s
# train Loss: 0.8872 Acc: 0.7140
# Time elapsed 210m 51s
# valid Loss: 2.2666 Acc: 0.6106
# Optimizer learning rate : 0.0100000
#
# Epoch 118/149
# ----------
# Time elapsed 212m 26s
# train Loss: 0.8332 Acc: 0.7264
# Time elapsed 212m 37s
# valid Loss: 2.3793 Acc: 0.6074
# Optimizer learning rate : 0.0100000
#
# Epoch 119/149
# ----------
# Time elapsed 214m 13s
# train Loss: 0.8498 Acc: 0.7297
# Time elapsed 214m 23s
# valid Loss: 1.4964 Acc: 0.6859
# Optimizer learning rate : 0.0100000
#
# Epoch 120/149
# ----------
# Time elapsed 215m 58s
# train Loss: 1.0432 Acc: 0.7099
# Time elapsed 216m 9s
# valid Loss: 3.0148 Acc: 0.5048
# Optimizer learning rate : 0.0100000
#
# Epoch 121/149
# ----------
# Time elapsed 217m 44s
# train Loss: 0.9363 Acc: 0.7118
# Time elapsed 217m 55s
# valid Loss: 1.6837 Acc: 0.7003
# Optimizer learning rate : 0.0100000
#
# Epoch 122/149
# ----------
# Time elapsed 219m 30s
# train Loss: 0.9079 Acc: 0.7264
# Time elapsed 219m 40s
# valid Loss: 1.3403 Acc: 0.6955
# Optimizer learning rate : 0.0100000
#
# Epoch 123/149
# ----------
# Time elapsed 221m 15s
# train Loss: 0.8552 Acc: 0.7230
# Time elapsed 221m 25s
# valid Loss: 0.8859 Acc: 0.7885
# Optimizer learning rate : 0.0100000
#
# Epoch 124/149
# ----------
# Time elapsed 223m 1s
# train Loss: 0.8659 Acc: 0.7322
# Time elapsed 223m 11s
# valid Loss: 1.0516 Acc: 0.7548
# Optimizer learning rate : 0.0100000
#
# Epoch 125/149
# ----------
# Time elapsed 224m 46s
# train Loss: 0.9027 Acc: 0.7164
# Time elapsed 224m 56s
# valid Loss: 1.1736 Acc: 0.7324
# Optimizer learning rate : 0.0100000
#
# Epoch 126/149
# ----------
# Time elapsed 226m 32s
# train Loss: 0.8472 Acc: 0.7247
# Time elapsed 226m 42s
# valid Loss: 2.2085 Acc: 0.6426
# Optimizer learning rate : 0.0100000
#
# Epoch 127/149
# ----------
# Time elapsed 228m 17s
# train Loss: 0.9019 Acc: 0.7295
# Time elapsed 228m 28s
# valid Loss: 2.2296 Acc: 0.6779
# Optimizer learning rate : 0.0100000
#
# Epoch 128/149
# ----------
# Time elapsed 230m 3s
# train Loss: 0.8555 Acc: 0.7297
# Time elapsed 230m 13s
# valid Loss: 1.0925 Acc: 0.7484
# Optimizer learning rate : 0.0100000
#
# Epoch 129/149
# ----------
# Time elapsed 231m 49s
# train Loss: 0.9516 Acc: 0.7170
# Time elapsed 231m 60s
# valid Loss: 1.9916 Acc: 0.6747
# Optimizer learning rate : 0.0100000
#
# Epoch 130/149
# ----------
# Time elapsed 233m 36s
# train Loss: 1.0516 Acc: 0.7063
# Time elapsed 233m 47s
# valid Loss: 3.0836 Acc: 0.6122
# Optimizer learning rate : 0.0100000
#
# Epoch 131/149
# ----------
# Time elapsed 235m 22s
# train Loss: 0.7052 Acc: 0.7544
# Time elapsed 235m 33s
# valid Loss: 2.9023 Acc: 0.6170
# Optimizer learning rate : 0.0100000
#
# Epoch 132/149
# ----------
# Time elapsed 237m 8s
# train Loss: 1.0075 Acc: 0.7143
# Time elapsed 237m 19s
# valid Loss: 0.9947 Acc: 0.7372
# Optimizer learning rate : 0.0100000
#
# Epoch 133/149
# ----------
# Time elapsed 238m 54s
# train Loss: 0.8362 Acc: 0.7287
# Time elapsed 239m 5s
# valid Loss: 1.1881 Acc: 0.7612
# Optimizer learning rate : 0.0100000
#
# Epoch 134/149
# ----------
# Time elapsed 240m 40s
# train Loss: 0.8324 Acc: 0.7274
# Time elapsed 240m 51s
# valid Loss: 1.4084 Acc: 0.7003
# Optimizer learning rate : 0.0100000
#
# Epoch 135/149
# ----------
# Time elapsed 242m 27s
# train Loss: 0.8230 Acc: 0.7335
# Time elapsed 242m 37s
# valid Loss: 1.7623 Acc: 0.6843
# Optimizer learning rate : 0.0100000
#
# Epoch 136/149
# ----------
# Time elapsed 244m 13s
# train Loss: 0.7937 Acc: 0.7360
# Time elapsed 244m 24s
# valid Loss: 1.7237 Acc: 0.6859
# Optimizer learning rate : 0.0100000
#
# Epoch 137/149
# ----------
# Time elapsed 245m 59s
# train Loss: 0.7469 Acc: 0.7421
# Time elapsed 246m 10s
# valid Loss: 1.1404 Acc: 0.7452
# Optimizer learning rate : 0.0100000
#
# Epoch 138/149
# ----------
# Time elapsed 247m 46s
# train Loss: 0.8283 Acc: 0.7293
# Time elapsed 247m 57s
# valid Loss: 1.0263 Acc: 0.7452
# Optimizer learning rate : 0.0100000
#
# Epoch 139/149
# ----------
# Time elapsed 249m 33s
# train Loss: 0.8055 Acc: 0.7268
# Time elapsed 249m 43s
# valid Loss: 1.2354 Acc: 0.6715
# Optimizer learning rate : 0.0100000
#
# Epoch 140/149
# ----------
# Time elapsed 251m 20s
# train Loss: 0.9266 Acc: 0.7141
# Time elapsed 251m 30s
# valid Loss: 1.2687 Acc: 0.6827
# Optimizer learning rate : 0.0100000
#
# Epoch 141/149
# ----------
# Time elapsed 253m 8s
# train Loss: 0.9791 Acc: 0.7186
# Time elapsed 253m 18s
# valid Loss: 1.6261 Acc: 0.6522
# Optimizer learning rate : 0.0100000
#
# Epoch 142/149
# ----------
# Time elapsed 254m 57s
# train Loss: 0.8766 Acc: 0.7310
# Time elapsed 255m 7s
# valid Loss: 1.8646 Acc: 0.6554
# Optimizer learning rate : 0.0100000
#
# Epoch 143/149
# ----------
# Time elapsed 256m 46s
# train Loss: 0.8922 Acc: 0.7280
# Time elapsed 256m 57s
# valid Loss: 2.6321 Acc: 0.6202
# Optimizer learning rate : 0.0100000
#
# Epoch 144/149
# ----------
# Time elapsed 258m 36s
# train Loss: 0.8118 Acc: 0.7354
# Time elapsed 258m 47s
# valid Loss: 0.9520 Acc: 0.7821
# Optimizer learning rate : 0.0100000
#
# Epoch 145/149
# ----------
# Time elapsed 260m 26s
# train Loss: 0.6983 Acc: 0.7542
# Time elapsed 260m 37s
# valid Loss: 0.9286 Acc: 0.7740
# Optimizer learning rate : 0.0100000
#
# Epoch 146/149
# ----------
# Time elapsed 262m 16s
# train Loss: 0.9474 Acc: 0.7186
# Time elapsed 262m 27s
# valid Loss: 2.0632 Acc: 0.5705
# Optimizer learning rate : 0.0100000
#
# Epoch 147/149
# ----------
# Time elapsed 264m 6s
# train Loss: 0.8774 Acc: 0.7316
# Time elapsed 264m 16s
# valid Loss: 1.3941 Acc: 0.7292
# Optimizer learning rate : 0.0100000
#
# Epoch 148/149
# ----------
# Time elapsed 265m 51s
# train Loss: 1.1489 Acc: 0.7044
# Time elapsed 266m 1s
# valid Loss: 1.3412 Acc: 0.7003
# Optimizer learning rate : 0.0100000
#
# Epoch 149/149
# ----------
# Time elapsed 267m 33s
# train Loss: 0.8377 Acc: 0.7368
# Time elapsed 267m 43s
# valid Loss: 1.0544 Acc: 0.7484
# Optimizer learning rate : 0.0100000
#
# Training complete in 267m 43s
# Best val Acc: 0.804487

# %% [markdown]
# ### 再继续训练所有层

# %%
for param in model_ft.parameters():
    param.requires_grad = True

# 再继续训练所有的参数，学习率调小一点
optimizer = optim.Adam(params_to_update, lr=1e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# 损失函数
criterion = nn.NLLLoss()

# %%
# Load the checkpoint

checkpoint = torch.load(filename)
best_acc = checkpoint['best_acc']
model_ft.load_state_dict(checkpoint['state_dict'])
optimizer.load_state_dict(checkpoint['optimizer'])
#model_ft.class_to_idx = checkpoint['mapping']

# %%
model_ft, val_acc_history, train_acc_history, valid_losses, train_losses, LRs  = train_model(model_ft, dataloaders, criterion, optimizer, num_epochs=10, is_inception=(model_name=="inception"))
# Out:
# Epoch 0/9
# ----------
# Time elapsed 1m 46s
# train Loss: 0.8866 Acc: 0.7257
# Time elapsed 1m 56s
# valid Loss: 1.2063 Acc: 0.7212
# C:\Users\15690\.conda\envs\ltc37\lib\site-packages\torch\optim\lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Optimizer learning rate : 0.0100000
#
# Epoch 1/9
# ----------
# Time elapsed 3m 43s
# train Loss: 0.9001 Acc: 0.7220
# Time elapsed 3m 53s
# valid Loss: 0.8901 Acc: 0.7997
# Optimizer learning rate : 0.0100000
#
# Epoch 2/9
# ----------
# Time elapsed 5m 40s
# train Loss: 0.9336 Acc: 0.7228
# Time elapsed 5m 50s
# valid Loss: 1.5984 Acc: 0.6779
# Optimizer learning rate : 0.0100000
#
# Epoch 3/9
# ----------
# Time elapsed 7m 37s
# train Loss: 0.7982 Acc: 0.7314
# Time elapsed 7m 47s
# valid Loss: 0.9915 Acc: 0.7612
# Optimizer learning rate : 0.0100000
#
# Epoch 4/9
# ----------
# Time elapsed 9m 33s
# train Loss: 1.0468 Acc: 0.7003
# Time elapsed 9m 43s
# valid Loss: 0.8742 Acc: 0.7885
# Optimizer learning rate : 0.0100000
#
# Epoch 5/9
# ----------
# Time elapsed 11m 30s
# train Loss: 0.9655 Acc: 0.7132
# Time elapsed 11m 40s
# valid Loss: 1.2927 Acc: 0.7035
# Optimizer learning rate : 0.0100000
#
# Epoch 6/9
# ----------
# Time elapsed 13m 27s
# train Loss: 0.8124 Acc: 0.7354
# Time elapsed 13m 37s
# valid Loss: 0.9111 Acc: 0.7788
# Optimizer learning rate : 0.0100000
#
# Epoch 7/9
# ----------
# Time elapsed 15m 25s
# train Loss: 0.7538 Acc: 0.7383
# Time elapsed 15m 35s
# valid Loss: 0.9376 Acc: 0.7853
# Optimizer learning rate : 0.0100000
#
# Epoch 8/9
# ----------
# Time elapsed 17m 22s
# train Loss: 0.9197 Acc: 0.7145
# Time elapsed 17m 32s
# valid Loss: 3.0721 Acc: 0.4038
# Optimizer learning rate : 0.0100000
#
# Epoch 9/9
# ----------
# Time elapsed 19m 18s
# train Loss: 0.8709 Acc: 0.7247
# Time elapsed 19m 28s
# valid Loss: 1.5609 Acc: 0.7083
# Optimizer learning rate : 0.0100000
#
# Training complete in 19m 28s
# Best val Acc: 0.799679

# %% [markdown]
# ### 测试网络效果
#
# 输入一张测试图像，看看网络的返回结果：
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# 注意预处理方法需相同

# %% [markdown]
# ### 加载训练好的模型

# %%
model_ft, input_size = initialize_model(model_name, CLASS, feature_extract, use_pretrained=True)

# GPU模式
model_ft = model_ft.to(device)

# 保存文件的名字
filename='checkpoint.pth'

# 加载模型
checkpoint = torch.load(filename)
best_acc = checkpoint['best_acc']
model_ft.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### 测试数据预处理
#
# - 测试数据处理方法需要跟训练时一直才可以
# - crop操作的目的是保证输入的大小是一致的
# - 标准化操作也是必须的，用跟训练数据相同的mean和std,但是需要注意一点训练数据是在0-1上进行标准化，所以测试数据也需要先归一化
# - 最后一点，PyTorch中颜色通道是第一个维度，跟很多工具包都不一样，需要转换

# %%
def process_image(image_path):
    # 读取测试数据
    img = Image.open(image_path)
    # Resize,thumbnail方法只能进行缩小，所以进行了判断
    if img.size[0] > img.size[1]:
        img.thumbnail((10000, 256))
    else:
        img.thumbnail((256, 10000))
    # Crop操作
    left_margin = (img.width-224)/2
    bottom_margin = (img.height-224)/2
    right_margin = left_margin + 224
    top_margin = bottom_margin + 224
    img = img.crop((left_margin, bottom_margin, right_margin,   
                      top_margin))
    # 相同的预处理方法
    img = np.array(img)/255
    mean = np.array([0.485, 0.456, 0.406]) #provided mean
    std = np.array([0.229, 0.224, 0.225]) #provided std
    img = (img - mean)/std
    
    # 注意颜色通道应该放在第一个位置
    img = img.transpose((2, 0, 1))
    
    return img

# %%
def imshow(image, ax=None, title=None):
    """展示数据"""
    if ax is None:
        fig, ax = plt.subplots()
    
    # 颜色通道还原
    image = np.array(image).transpose((1, 2, 0))
    
    # 预处理还原
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    ax.set_title(title)
    
    return ax

# %%
data_transform1 = {

     "singlepic":transforms.Compose([transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
   
    ]),
}

# %%
batch_size1 = 32
CLASS = 3
image_datasets1 = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transform1[x]) for x in ['singlepic']}
dataloaders1 = {x: torch.utils.data.DataLoader(image_datasets1[x], batch_size=batch_size1, shuffle=False) for x in ['singlepic']}
dataset_sizes1 = {x: len(image_datasets1[x]) for x in ['singlepic']}
class_names1 = image_datasets1['singlepic'].classes

# %%
# 得到一个batch的测试数据
dataiter1 = iter(dataloaders1["singlepic"])
images, labels = dataiter1.next()

model_ft.eval()

if train_on_gpu:
    output = model_ft(images.cuda())
else:
    output = model_ft(images)

# %%
_, preds_tensor = torch.max(output, 1)

preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())
preds
# Out:
# array(0, dtype=int64)
